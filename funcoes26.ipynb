# %%
b = 2
a = 1
c = 3

# %%
delta = 6**2 - 4*5*6

# %%
delta
# Out:
# -8

# %%
not True
# Out:
# False

# %%
not -2
# Out:
# False

# %%
# Declaração
def é_par(n):
    resto = n % 2
    return not resto

def resto_por_2(n):
    return n%2

# %%
é_par(1000)
# Out:
# True

# %%
def soma_numeros(a, b):
    soma = a + b
    return soma 

s = soma_numeros(8, 9)

# %%
print(s)
# Out:
# 17

# %%
x = soma_numeros

# %%
x(4,5)
# Out:
# 9

# %%
print(x)
# Out:
# <function soma_numeros at 0x107834180>

# %%
print()

# %%
y = print

# %%
y("olá mundo")
# Out:
# olá mundo

# %%
import math

# %%
math.cos(math.pi)
# Out:
# -1.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.radians(45)
# Out:
# 0.7853981633974483

# %%
math.degrees(math.pi/2)
# Out:
# 90.0

# %%
"2.3".isnumeric()
# Out:
# False

# %%
"23".isdigit()
# Out:
# True

# %%
"2.3".isdecimal()
# Out:
# False
